# %% [markdown]
# <a href="https://colab.research.google.com/github/fabianofernandes/Colab/blob/main/Aula_0_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Criando um conjunto de perguntas a serem respondidas na análise dos dados!
# ![Análise_Supermercado.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
df_supermercado=pd.read_csv("/content/supermarket_sales.csv")
df_supermercado.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# 1 - Qual o faturamento total por filial?
#
# Agrupo (Groupby) por filial, depois eu pego o que eu quero ver (Total) e lucro bruto (gross income)

# %%
df_supermercado.groupby("City")[["Total", "gross income"]].sum()
# Out:
#                  Total  gross income
# City
# Mandalay   106197.6720     5057.0320
# Naypyitaw  110568.7065     5265.1765
# Yangon     106200.3705     5057.1605

# %% [markdown]
# 2 -  Qual o percentual de participação na receita de cada tipo de produto?

# %% [markdown]
# 3 - Como está distribuído o tio de procuto consumido por gênero?

# %% [markdown]
# 4 - Qual foi o faturamento por mês?

# %% [markdown]
# 5 - Qual foi a média de avaliação por cada filial em janeiro de 2019?

# %% [markdown]
# 6 - Como se distribui o gasto por tipo de consumidor emc ad filial?
